# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
from nltk.corpus import wordnet as wn

# %%
def get_wordnet_relations(word):
    results = {
        "synonyms": set(),
        "antonyms": set(),
        "hypernyms": set(),
        "hyponyms": set()
    }

    for synset in wn.synsets(word):
        # Synonyms
        for lemma in synset.lemmas():
            results["synonyms"].add(lemma.name())

            # Antonyms
            if lemma.antonyms():
                results["antonyms"].add(lemma.antonyms()[0].name())

        # Hypernyms
        for hypernym in synset.hypernyms():
            for lemma in hypernym.lemmas():
                results["hypernyms"].add(lemma.name())

        # Hyponyms
        for hyponym in synset.hyponyms():
            for lemma in hyponym.lemmas():
                results["hyponyms"].add(lemma.name())

    return results

# %%
word = "happy"
relations = get_wordnet_relations(word)

print("Word:", word)
print("Synonyms:", relations["synonyms"])
print("Antonyms:", relations["antonyms"])
print("Hypernyms:", relations["hypernyms"])
print("Hyponyms:", relations["hyponyms"])
# Out:
# Word: happy
# Synonyms: {'happy', 'glad', 'well-chosen', 'felicitous'}
# Antonyms: {'unhappy'}
# Hypernyms: set()
# Hyponyms: set()

# %%
def analyze_text(text):
    words = set(text.lower().split())
    analysis = {}

    for word in words:
        analysis[word] = get_wordnet_relations(word)

    return analysis

# %%
text = "The happy child felt joyful but not sad."
results = analyze_text(text)

for word, relations in results.items():
    print(f"\n🔹 Word: {word}")
    print("  Synonyms:", relations["synonyms"])
    print("  Antonyms:", relations["antonyms"])
    print("  Hypernyms:", relations["hypernyms"])
    print("  Hyponyms:", relations["hyponyms"])
# Out:
# 🔹 Word: happy
#   Synonyms: {'happy', 'glad', 'well-chosen', 'felicitous'}
#   Antonyms: {'unhappy'}
#   Hypernyms: set()
#   Hyponyms: set()
#
# 🔹 Word: the
#   Synonyms: set()
#   Antonyms: set()
#   Hypernyms: set()
#   Hyponyms: set()
#
# 🔹 Word: child
#   Synonyms: {'nipper', 'tike', 'baby', 'small_fry', 'fry', 'shaver', 'child', 'youngster', 'tyke', 'tiddler', 'nestling', 'kid', 'minor'}
#   Antonyms: {'parent'}
#   Hypernyms: {'juvenile_person', 'juvenile', 'offspring', 'person', 'descendent', 'somebody', 'mortal', 'issue', 'descendant', 'someone', 'progeny', 'individual', 'soul'}
#   Hyponyms: {'scalawag', 'female_offspring', 'kindergartener', 'yearling', 'piccaninny', 'foster-child', 'army_brat', 'stepchild', 'wonder_child', 'urchin', 'fosterling', 'waif', 'baby', 'infant', 'orphan', 'child_prodigy', 'preschooler', 'street_child', 'bairn', 'man-child', 'infant_prodigy', 'imp', 'sprog', 'pickaninny', 'babe', 'male_offspring', 'foster_child', 'peanut', 'changeling', 'scamp', 'bambino', 'picaninny', 'tot', 'monkey', 'toddler', 'scallywag', 'kiddy', 'rapscallion', 'poster_child', 'silly', 'kindergartner', 'rascal', 'buster'}
#
# 🔹 Word: felt
#   Synonyms: {'mat_up', 'matt-up', 'mat', 'experience', 'find', 'sense', 'palpate', 'felt', 'feel', 'finger', 'felt_up', 'matte', 'matte_up'}
#   Antonyms: set()
#   Hypernyms: {'experience', 'fabric', 'think', 'conclude', 'snarl', 'seek', 'look', 'believe', 'touch', 'textile', 'conceive', 'look_for', 'see', 'seem', 'consider', 'reason', 'material', 'cloth', 'mat', 'cover', 'search', 'reason_out', 'regain', 'entangle', 'be', 'appear', 'change', 'find', 'comprehend', 'perceive', 'tangle', 'go_through'}
#   Hyponyms: {'sympathize', 'harbor', 'congratulate', 'pride', 'feel_like_a_million_dollars', 'plume', 'scrabble', 'shine', 'regret', 'pride_oneself', 'take_pride', 'beam', 'rue', 'smolder', 'hold', 'entertain', 'see_red', 'anger', 'grope_for', 'glow', 'incline', 'sympathise', 'suffer', 'cool_off', 'repent', 'recapture', 'fume', 'harbour', 'sadden', 'chafe', 'crawl', 'suffocate', 'joy', 'rejoice', 'smoulder', 'feel_like_a_million', 'nurse', 'fly_high', 'radiate', 'die', 'burn'}
#
# 🔹 Word: not
#   Synonyms: {'non', 'not'}
#   Antonyms: set()
#   Hypernyms: set()
#   Hyponyms: set()
#
# 🔹 Word: sad.
#   Synonyms: set()
#   Antonyms: set()
#   Hypernyms: set()
#   Hyponyms: set()
#
# 🔹 Word: but
#   Synonyms: {'merely', 'simply', 'only', 'just', 'but'}
#   Antonyms: set()
#   Hypernyms: set()
#   Hyponyms: set()
#
# 🔹 Word: joyful
#   Synonyms: {'gleeful', 'elated', 'jubilant', 'joyful'}
#   Antonyms: {'sorrowful'}
#   Hypernyms: set()
#   Hyponyms: set()
